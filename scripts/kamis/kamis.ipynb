# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from farmbase.config import settings
from sqlalchemy.ext.asyncio import AsyncSession, create_async_engine
from sqlalchemy.orm import sessionmaker

# %%
df = pd.read_csv("data/kamis_market_prices.csv")

# Replace all cells that contain only "-" (with or without surrounding whitespace) with None
df.replace(r"^\s*-\s*$", pd.NA, regex=True, inplace=True)


def split_price_column(df, column, prefix):
    """Split a 'price/unit' column into price, unit, and currency."""
    split_cols = df[column].str.split("/", expand=True)
    df[f"{prefix}_price"] = pd.to_numeric(split_cols[0], errors="coerce")
    df[f"{prefix}_unit"] = split_cols[1]
    df[f"{prefix}_ccy"] = "KES"
    return df


# Apply transformations
df = split_price_column(df, "Wholesale", "wholesale")
df = split_price_column(df, "Retail", "retail")

# Drop the original columns
df.drop(columns=["Wholesale", "Retail", "source_date"], inplace=True)
df
# Out:
#                     Market                Commodity  Classification Grade  \
# 0                   Awendo       Beans (Mwezi Moja)            <NA>  <NA>
# 1                   Awendo  Beans (Canadian wonder)            <NA>  <NA>
# 2                   Awendo               Fertilizer             NPK  <NA>
# 3                   Awendo               Fertilizer             NPK  <NA>
# 4                   Awendo               Fertilizer             DAP  <NA>
# ...                    ...                      ...             ...   ...
# 911958  Kipini Fish market                  Rayfish           Dried  <NA>
# 911959  Kipini Fish market   Rabbitfish (Tafi/Tasi)  Frozen/Chilled  <NA>
# 911960  Kipini Fish market       Fresh Water Shrimp           Dried  <NA>
# 911961  Kipini Fish market       Fresh Water Shrimp           Fresh  <NA>
# 911962  Kipini Fish market   African butter catfish           Fresh  <NA>
#
#          Sex  Supply Volume      County        Date  wholesale_price  \
# 0       <NA>         5000.0      Migori  2021-05-24            60.00
# 1       <NA>         8000.0      Migori  2021-05-24            71.11
# 2       <NA>         1800.0      Migori  2021-05-24            36.00
# 3       <NA>         2500.0      Migori  2021-05-24            48.00
# 4       <NA>         5000.0      Migori  2021-05-24            63.00
# ...      ...            ...         ...         ...              ...
# 911958  <NA>           22.0  Tana-River  2025-06-09           280.00
# 911959  <NA>           24.0  Tana-River  2025-06-09           250.00
# 911960  <NA>           58.0  Tana-River  2025-06-09           200.00
# 911961  <NA>           76.0  Tana-River  2025-06-09           100.00
# 911962  <NA>           31.0  Tana-River  2025-06-09           100.00
#
#        wholesale_unit wholesale_ccy  retail_price retail_unit retail_ccy
# 0                  Kg           KES         68.89          Kg        KES
# 1                  Kg           KES         75.56          Kg        KES
# 2                  Kg           KES         40.00          Kg        KES
# 3                  Kg           KES         54.00          Kg        KES
# 4                  Kg           KES         68.00          Kg        KES
# ...               ...           ...           ...         ...        ...
# 911958             Kg           KES        350.00          Kg        KES
# 911959             Kg           KES        330.00          Kg        KES
# 911960             Kg           KES        270.00          Kg        KES
# 911961             Kg           KES        150.00          Kg        KES
# 911962             Kg           KES        160.00          Kg        KES
#
# [911963 rows x 14 columns]

# %%
from farmbase import Commodity
from tqdm import tqdm

# Create async DB engine and session
# DATABASE_URL = "postgresql+asyncpg://user:pass@localhost/dbname"  # replace with actual
engine = create_async_engine(settings.SQLALCHEMY_DATABASE_URI, echo=True)
AsyncSessionLocal = sessionmaker(engine, class_=AsyncSession, expire_on_commit=False)

df[["Commodity", "Classification", "Grade", "Sex"]]


async def populate_commodities(_com):
    async with AsyncSessionLocal() as session:
        for _, row in tqdm(_com.iterrows(), total=len(_com), desc="Inserting Commodities"):
            grade_value = None if pd.isna(row.Grade) else row.Grade
            classificatio_value = None if pd.isna(row.Classification) else row.Classification
            sex_value = None if pd.isna(row.Sex) else row.Sex.upper()
            com = Commodity(name=row.Commodity, classification=classificatio_value, grade=grade_value, sex=sex_value)
            session.add(com)
        await session.commit()
        print("✅ Finished populating commodities.")


df2 = df[["Commodity", "Classification", "Grade", "Sex"]].drop_duplicates()
df2 = df2[~df2.Commodity.isna()]

await populate_commodities(df2)
# Out:
# Inserting Commodities: 100%|██████████| 808/808 [00:00<00:00, 29121.35it/s]
# 2025-06-10 16:32:27,188 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-06-10 16:32:27,188 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-10 16:32:27,194 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-06-10 16:32:27,195 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-10 16:32:27,198 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-06-10 16:32:27,199 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-10 16:32:27,202 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-10 16:32:27,210 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.commodity (name, classification, grade, sex) SELECT p0::VARCHAR, p1::VARCHAR, p2::VARCHAR, p3::gender_enum FROM (VALUES ($1::VARCHAR, $2::VARCHAR, $3::VARCHAR, $4::gender_enum, 0), ($5::VARCHAR, $6::VARCHAR, $7::VARCHAR, $8: ... 59313 characters truncated ... nter) ORDER BY sen_counter RETURNING farmbase_core.commodity.id, farmbase_core.commodity.id AS id__1
# 2025-06-10 16:32:27,211 INFO sqlalchemy.engine.Engine [generated in 0.00125s (insertmanyvalues) 1/1 (ordered)] ('Beans (Mwezi Moja)', None, None, None, 'Beans (Canadian wonder)', None, None, None, 'Fertilizer', 'NPK', None, None, 'Fertilizer', 'DAP', None, None, 'Fertilizer', 'CAN', None, None, 'Goat', 'East African Goat', None, 'FEMALE', 'Goat', 'East African Goat', None, 'MALE', 'Chicken', 'Improved Kienyeji', None, 'MALE', 'Chicken', 'Improved Kienyeji', None, 'FEMALE', 'Donkey', None, None, 'FEMALE', 'Donkey', None, None, 'MALE', 'Goat', 'Mixed', 'Grade 2 ', 'FEMALE', 'Chicken', 'Indigenous' ... 3132 parameters truncated ... 'Grade 2 ', 'FEMALE', 'Chicken', 'Ayrshire', None, 'MALE', 'Duck', 'Mallard', 'Grade 2', 'MALE', 'Cattle', None, 'Grade 4 ', 'CASTRATE', 'Rice', 'Yellow Maize', None, None, 'Fertilizer', 'Urea', None, None, 'Fertilizer', 'Sulphate of Ammonia', None, None, 'Queenfish (Pandu)', 'Dried', None, None, 'Dragon Fruit', None, None, None, 'Cashewnuts (Korosho)', None, None, None, 'Chicken', 'Hamshire', None, 'FEMALE', 'Fertilizer', 'Ammonia Anhydrous', None, None, 'Rabbit', 'Flemish Giant', None, 'MALE')
# 2025-06-10 16:32:27,272 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Finished populating commodities.

# %%
# df2 = df[['Commodity', 'Classification', 'Grade', 'Sex']].drop_duplicates()
df2[~df2.Commodity.isna()].Sex.unique()
# Out:
# array([<NA>, 'Female', 'Male', 'Castrate'], dtype=object)

# %%
from farmbase.market.models import Market

markets = pd.read_csv("markets.csv")

# Create async DB engine and session
# DATABASE_URL = "postgresql+asyncpg://user:pass@localhost/dbname"  # replace with actual
engine = create_async_engine(settings.SQLALCHEMY_DATABASE_URI, echo=True)
AsyncSessionLocal = sessionmaker(engine, class_=AsyncSession, expire_on_commit=False)


async def populate_markets(_markets):
    async with AsyncSessionLocal() as session:
        for _, row in tqdm(_markets.iterrows(), total=len(_markets), desc="Inserting Markets"):
            region = Market(name=row.market, location=f"POINT({row.lon} {row.lat})")
            session.add(region)
        await session.commit()
        print("✅ Finished populating markets.")


await populate_markets(markets)
# Out:
# Inserting Markets: 100%|██████████| 286/286 [00:00<00:00, 22419.37it/s]
# 2025-06-10 16:32:30,340 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-06-10 16:32:30,341 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-10 16:32:30,344 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-06-10 16:32:30,344 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-10 16:32:30,348 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-06-10 16:32:30,348 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-10 16:32:30,350 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-10 16:32:30,353 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market (name, location) SELECT p0::VARCHAR, p1::geometry(POINT,4326) FROM (VALUES ($1::VARCHAR, ST_GeomFromEWKT($2), 0), ($3::VARCHAR, ST_GeomFromEWKT($4), 1), ($5::VARCHAR, ST_GeomFromEWKT($6), 2), ($7::VARCHAR, ST_GeomFrom ... 12596 characters truncated ... , farmbase_core.market.created_at, farmbase_core.market.updated_at, farmbase_core.market.id AS id__1
# 2025-06-10 16:32:30,354 INFO sqlalchemy.engine.Engine [generated in 0.00036s (insertmanyvalues) 1/1 (ordered)] ('Awendo', 'POINT(34.52846 -0.87469)', 'Aram', 'POINT(35.83546 0.161726)', 'Kababu', 'POINT(37.65 0.05)', 'Elwak Livestock Market', 'POINT(40.8318 2.831778)', 'Akala', 'POINT(34.42605 -0.059466)', 'Kangeta', 'POINT(37.8833 0.2833)', 'Old port Fish Market', 'POINT(39.67955 -4.058054)', 'Elwak Market', 'POINT(40.93211 2.810566)', 'Rongo', 'POINT(34.59862 -0.818652)', 'Kabiyet Market', 'POINT(35.0833 0.4)', 'Ortum', 'POINT(35.35629 1.44038)', 'Kajiado Market', 'POINT(36.78832 -1.841601)', 'Ngong market', 'POINT(36.65675 -1.3598)', 'Taveta', 'POINT(37.6833 -3.4)', 'Katito', 'POINT(34.97325 -0.274214)', 'Garissa Soko Mugdi', 'POINT(40.35641 -0.523633)', 'Kagio', 'POINT(37.25 -0.6166)', 'Marigat', 'POINT(36.03507 0.438553)', 'Masii Crops', 'POINT(37.43919 -1.4608)', 'Eldoret Main', 'POINT(35.27274 0.518128)', 'Takaba Livestock Market', 'POINT(40.2242 3.398734)', 'Isiolo Fresh Produce', 'POINT(38.7479 1.00606)', 'Eldama Ravine', 'POINT(35.73309 -0.01985)', 'Kongowea', 'POINT(39.68691 -4.038018)', 'Karatina', 'POINT(37.12522 -0.482246)' ... 472 parameters truncated ... 'Loyangalani fishing cooperative', 'POINT(36.71673 2.75837)', 'Nanyuki Livestock Market', 'POINT(37.07463 0.01403)', 'Emining Livestock Market', 'POINT(35.8888 0.143695)', 'Kimanjo Livestock Market', 'POINT(37.01109 0.476694)', 'Voi Wholesale', 'POINT(38.8036 -3.559275)', 'Voi Retail', 'POINT(38.8036 -3.559275)', 'Taveta Retail Market', 'POINT(37.6833 -3.4)', 'Mghange', 'POINT(38.31295 -3.40107)', 'Keroka Kisii', 'POINT(34.94715 -0.779212)', 'Rumuruti Food Crops Market', 'POINT(36.54037 0.26903)', 'Mandera Market', 'POINT(40.70562 3.228533)', 'Balambala Livestock Market', 'POINT(39.08199 0.108437)', 'Bondeni', 'POINT(36.08299 -0.293796)', 'Khayega', 'POINT(34.77314 0.206242)', 'Nambacha Market', 'POINT(34.66735 0.394815)', 'Naroosura Livestock Market', 'POINT(35.76971 -1.359155)', 'Isebania Market', 'POINT(34.47922 -1.240322)', 'Sega', 'POINT(34.2258 0.2558)', 'Lamu', 'POINT(40.90106 -2.26754)', 'Tankar Market', 'POINT(40.05 1.75)', 'Kimumu - Bahati', 'POINT(35.28855 0.545695)', 'Butere Livestock Market', 'POINT(34.49813 0.216308)', 'Bomet Market', 'POINT(35.23996 -0.719605)', 'Kipini Fish market', 'POINT(40.52725 -2.528173)', 'Cheptulu', 'POINT(34.8646 0.129513)')
# 2025-06-10 16:32:30,374 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Finished populating markets.

# %%
from pprint import pprint

from farmbase import MarketPrice, Market, Commodity
from sqlalchemy import select

# Create async DB engine and session
# DATABASE_URL = "postgresql+asyncpg://user:pass@localhost/dbname"  # replace with actual
engine = create_async_engine(settings.sqlalchemy_database_uri, echo=True)
AsyncSessionLocal = sessionmaker(engine, class_=AsyncSession, expire_on_commit=False)


async def load_market_prices(df: pd.DataFrame):
    """
    Loads market price data from a pandas DataFrame into the database.
    It creates Commodity and Market entries if they don't exist,
    then links MarketPrice records to them.
    Performs lookups to Commodity and Market tables efficiently.
    Uses SQLAlchemy 2.0 style for queries and session management.
    """
    # Use 'with' statement for session management for proper closing
    async with AsyncSessionLocal() as session:
        try:
            # Convert 'Date' column to datetime.date objects
            df["Date"] = pd.to_datetime(df["Date"], errors="coerce").dt.date

            # --- Pre-load existing Markets ---
            print("Pre-loading existing Markets...")
            # Use await session.execute(select(Market))
            result = await session.execute(select(Market))
            market_lookup = {market.name: market for market in result.scalars().all()}
            print(f"Found {len(market_lookup)} existing markets.")

            # --- Pre-load existing Commodities ---
            print("Pre-loading existing Commodities...")
            commodity_lookup = {}
            # Use await session.execute(select(Commodity))
            result = await session.execute(select(Commodity))
            for commodity in result.scalars().all():
                sex_value = commodity.sex.value if commodity.sex else None
                commodity_lookup[(commodity.name, commodity.classification, commodity.grade, sex_value)] = commodity
            print(f"Found {len(commodity_lookup)} existing commodities.")
            pprint(commodity_lookup)

            for index, row in df.iterrows():
                # --- Handle Market Lookup/Creation ---
                market_name = row["Market"]
                market_obj = market_lookup.get(market_name)

                if not market_obj:
                    print(f"no market with name: {market_name}, {row}")
                    continue

                # --- Handle Commodity Lookup/Creation ---
                commodity_name = row["Commodity"]
                if pd.isna(commodity_name):
                    print(f"No commodity name: {row}")
                    continue
                classification = row["Classification"] if pd.notna(row["Classification"]) else None
                grade = row["Grade"] if pd.notna(row["Grade"]) else None

                sex_str = None if pd.isna(row["Sex"]) else row["Sex"].lower()
                commodity_key = (commodity_name, classification, grade, sex_str)
                commodity_obj = commodity_lookup.get(commodity_key)

                if not commodity_obj:
                    raise Exception(f"no commodity with key: {commodity_key}")

                # --- Create MarketPrice entry ---
                market_price_obj = MarketPrice(
                    market_id=market_obj.id,
                    commodity_id=commodity_obj.id,
                    date=row["Date"],
                    supply_volume=row["Supply Volume"] if pd.notna(row["Supply Volume"]) else None,
                    wholesale_price=row["wholesale_price"] if pd.notna(row["wholesale_price"]) else None,
                    wholesale_unit=row["wholesale_unit"] if pd.notna(row["wholesale_unit"]) else None,
                    wholesale_ccy=row["wholesale_ccy"] if pd.notna(row["wholesale_ccy"]) else None,
                    retail_price=row["retail_price"] if pd.notna(row["retail_price"]) else None,
                    retail_unit=row["retail_unit"] if pd.notna(row["retail_unit"]) else None,
                    retail_ccy=row["retail_ccy"] if pd.notna(row["retail_ccy"]) else None,
                )
                session.add(market_price_obj)

            await session.commit()  # Await commit
            print("\nSuccessfully loaded all market prices into the database.")

        except Exception as e:
            await session.rollback()
            print(f"\nAn error occurred: {e}. Rolling back transaction.")
        # 'finally' block is not needed with 'with' statement for session.close() as it's handled automatically


await load_market_prices(
    df.drop_duplicates(subset=["Market", "Commodity", "Classification", "Grade", "Sex", "Date"], keep="first")
)
# Out:
# Pre-loading existing Markets...
# 2025-06-20 14:41:32,906 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-06-20 14:41:32,906 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-20 14:41:32,910 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-06-20 14:41:32,910 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-20 14:41:32,914 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-06-20 14:41:32,914 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-20 14:41:32,916 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-20 14:41:32,950 INFO sqlalchemy.engine.Engine SELECT farmbase_core.market.id, farmbase_core.market.name, ST_AsEWKB(farmbase_core.market.location) AS location, farmbase_core.market.created_at, farmbase_core.market.updated_at
# FROM farmbase_core.market
# 2025-06-20 14:41:32,951 INFO sqlalchemy.engine.Engine [generated in 0.00066s] ()
# Found 286 existing markets.
# Pre-loading existing Commodities...
# 2025-06-20 14:41:32,989 INFO sqlalchemy.engine.Engine SELECT farmbase_core.commodity.id, farmbase_core.commodity.name, farmbase_core.commodity.classification, farmbase_core.commodity.grade, farmbase_core.commodity.sex
# FROM farmbase_core.commodity
# 2025-06-20 14:41:32,989 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ()
# /var/folders/5d/c4d7d1814b33g1r6_cn3h87w0000gn/T/ipykernel_79913/3975772009.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Date"], errors="coerce").dt.date
# Found 808 existing commodities.
# {('African butter catfish', 'Dried', None, None): <Commodity(id=538, name='African butter catfish')>,
#  ('African butter catfish', 'Fresh', None, None): <Commodity(id=402, name='African butter catfish')>,
#  ('African butter catfish', 'Frozen/Chilled', None, None): <Commodity(id=642, name='African butter catfish')>,
#  ('African butter catfish', 'Smoked', None, None): <Commodity(id=567, name='African butter catfish')>,
#  ('Alestes', 'Dried', None, None): <Commodity(id=467, name='Alestes')>,
#  ('Amaranthus (Terere)', None, None, None): <Commodity(id=72, name='Amaranthus (Terere)')>,
#  ('Anchovies', 'Dried', None, None): <Commodity(id=500, name='Anchovies')>,
#  ('Anchovies', 'Fresh', None, None): <Commodity(id=339, name='Anchovies')>,
#  ('Apples', 'Green', None, None): <Commodity(id=266, name='Apples')>,
#  ('Apples', 'Red', None, None): <Commodity(id=279, name='Apples')>,
#  ('Apples', None, None, None): <Commodity(id=120, name='Apples')>,
#  ('Arrow Root', None, None, 'male'): <Commodity(id=257, name='Arrow Root')>,
#  ('Arrow Root', None, None, None): <Commodity(id=96, name='Arrow Root')>,
#  ('Avocado', None, None, 'male'): <Commodity(id=240, name='Avocado')>,
#  ('Avocado', 'Fuerte', None, None): <Commodity(id=98, name='Avocado')>,
#  ('Avocado', 'Hass', None, None): <Commodity(id=150, name='Avocado')>,
#  ('Avocado', 'Local', None, None): <Commodity(id=58, name='Avocado')>,
#  ('Avocado', None, None, None): <Commodity(id=219, name='Avocado')>,
#  ('Banana (Cooking)', None, None, None): <Commodity(id=108, name='Banana (Cooking)')>,
#  ('Banana (Plantain)', None, None, None): <Commodity(id=110, name='Banana (Plantain)')>,
#  ('Banana (Ripening)', 'Cooking Banana', None, None): <Commodity(id=220, name='Banana (Ripening)')>,
#  ('Banana (Ripening)', 'Cooking Banana', None, 'male'): <Commodity(id=241, name='Banana (Ripening)')>,
#  ('Banana (Ripening)', 'Ripe Banana', None, None): <Commodity(id=221, name='Banana (Ripening)')>,
#  ('Banana (Ripening)', None, None, None): <Commodity(id=57, name='Banana (Ripening)')>,
#  ('Barbus', 'Dried', None, None): <Commodity(id=653, name='Barbus')>,
#  ('Barracuda(Kasumba)', 'Dried', None, None): <Commodity(id=664, name='Barracuda(Kasumba)')>,
#  ('Barracuda(Kasumba)', 'Fresh', None, None): <Commodity(id=337, name='Barracuda(Kasumba)')>,
#  ('Barracuda(Kasumba)', 'Fried', None, None): <Commodity(id=334, name='Barracuda(Kasumba)')>,
#  ('Beans (Canadian wonder)', None, None, 'male'): <Commodity(id=262, name='Beans (Canadian wonder)')>,
#  ('Beans (Canadian wonder)', None, None, None): <Commodity(id=2, name='Beans (Canadian wonder)')>,
#  ('Beans (Mwezi Moja)', None, None, None): <Commodity(id=1, name='Beans (Mwezi Moja)')>,
#  ('Beans (Mwitemania)', None, None, None): <Commodity(id=126, name='Beans (Mwitemania)')>,
#  ('Beans (Yellow-Green)', None, None, None): <Commodity(id=82, name='Beans (Yellow-Green)')>,
#  ('Beans Red Haricot (Wairimu)', None, None, 'male'): <Commodity(id=261, name='Beans Red Haricot (Wairimu)')>,
#  ('Beans Red Haricot (Wairimu)', None, None, None): <Commodity(id=118, name='Beans Red Haricot (Wairimu)')>,
#  ('Beans Rosecoco', None, None, 'male'): <Commodity(id=260, name='Beans Rosecoco')>,
#  ('Beans Rosecoco', None, None, None): <Commodity(id=81, name='Beans Rosecoco')>,
#  ('Beans Rosecoco (Nyayo)', None, None, None): <Commodity(id=79, name='Beans Rosecoco (Nyayo)')>,
#  ('Black bass', 'Dried', None, None): <Commodity(id=403, name='Black bass')>,
#  ('Black bass', 'Fresh', None, None): <Commodity(id=302, name='Black bass')>,
#  ('Black bass', 'Frozen/Chilled', None, None): <Commodity(id=793, name='Black bass')>,
#  ('Black bass', 'Smoked', None, None): <Commodity(id=794, name='Black bass')>,
#  ('Black nightshade (Managu/ Osuga)', None, None, 'male'): <Commodity(id=237, name='Black nightshade (Managu/ Osuga)')>,
#  ('Black nightshade (Managu/ Osuga)', None, None, None): <Commodity(id=71, name='Black nightshade (Managu/ Osuga)')>,
#  ('Broccoli', None, None, None): <Commodity(id=136, name='Broccoli')>,
#  ('Butternuts', None, None, None): <Commodity(id=135, name='Butternuts')>,
#  ('Cabbages', None, None, 'male'): <Commodity(id=243, name='Cabbages')>,
#  ('Cabbages', None, None, None): <Commodity(id=86, name='Cabbages')>,
#  ('Camel', 'Gabra/Redille', 'Grade 1 ', 'female'): <Commodity(id=550, name='Camel')>,
#  ('Camel', 'Gabra/Redille', 'Grade 1 ', 'male'): <Commodity(id=517, name='Camel')>,
#  ('Camel', 'Gabra/Redille', 'Grade 2', 'female'): <Commodity(id=580, name='Camel')>,
#  ('Camel', 'Gabra/Redille', 'Grade 2', 'male'): <Commodity(id=527, name='Camel')>,
#  ('Camel', 'Gabra/Redille', 'Grade 3', 'female'): <Commodity(id=603, name='Camel')>,
#  ('Camel', 'Gabra/Redille', 'Grade 3', 'male'): <Commodity(id=484, name='Camel')>,
#  ('Camel', 'Gabra/Redille', 'Grade 4', 'female'): <Commodity(id=539, name='Camel')>,
#  ('Camel', 'Gabra/Redille', 'Grade 4', 'male'): <Commodity(id=558, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 1 ', 'castrate'): <Commodity(id=541, name='Camel')>,
#  ('Camel', 'Somali', None, 'male'): <Commodity(id=547, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 2', 'castrate'): <Commodity(id=577, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 3', 'female'): <Commodity(id=555, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 1 ', 'male'): <Commodity(id=533, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 2', 'male'): <Commodity(id=562, name='Camel')>,
#  ('Camel', 'Turkana', None, 'male'): <Commodity(id=570, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 1 ', 'castrate'): <Commodity(id=604, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 1 ', 'female'): <Commodity(id=584, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 2', 'female'): <Commodity(id=606, name='Camel')>,
#  ('Camel', None, None, 'male'): <Commodity(id=607, name='Camel')>,
#  ('Camel', 'Gabra/Redille', 'Grade 1 ', 'castrate'): <Commodity(id=733, name='Camel')>,
#  ('Camel', 'Gabra/Redille', None, 'female'): <Commodity(id=737, name='Camel')>,
#  ('Camel', 'Gabra/Redille', None, 'male'): <Commodity(id=734, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 1 ', 'female'): <Commodity(id=331, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 1 ', 'male'): <Commodity(id=174, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 2', 'female'): <Commodity(id=323, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 2', 'male'): <Commodity(id=270, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 3', 'male'): <Commodity(id=316, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 4', 'female'): <Commodity(id=315, name='Camel')>,
#  ('Camel', 'Somali', 'Grade 4', 'male'): <Commodity(id=271, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 2', 'castrate'): <Commodity(id=619, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 3', 'female'): <Commodity(id=691, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 3', 'male'): <Commodity(id=729, name='Camel')>,
#  ('Camel', 'Turkana', 'Grade 4', 'male'): <Commodity(id=735, name='Camel')>,
#  ('Camel', None, 'Grade 1 ', 'female'): <Commodity(id=749, name='Camel')>,
#  ('Camel', None, 'Grade 1 ', 'male'): <Commodity(id=702, name='Camel')>,
#  ('Camel', None, 'Grade 2', 'male'): <Commodity(id=748, name='Camel')>,
#  ('Camel Hide', None, 'Grade 1', None): <Commodity(id=674, name='Camel Hide')>,
#  ('Camel Hide', None, 'Grade 2', None): <Commodity(id=698, name='Camel Hide')>,
#  ('Camel Hide', None, 'Grade 3', None): <Commodity(id=775, name='Camel Hide')>,
#  ('Camel Milk(At collection point)', None, None, None): <Commodity(id=37, name='Camel Milk(At collection point)')>,
#  ('Camel meat', None, None, None): <Commodity(id=38, name='Camel meat')>,
#  ('Camel milk(Processed)', None, None, None): <Commodity(id=267, name='Camel milk(Processed)')>,
#  ('Capsicums', None, None, None): <Commodity(id=90, name='Capsicums')>,
#  ('Carrots', None, None, 'male'): <Commodity(id=252, name='Carrots')>,
#  ('Carrots', None, None, None): <Commodity(id=94, name='Carrots')>,
#  ('Cashewnuts (Korosho)', None, None, None): <Commodity(id=805, name='Cashewnuts (Korosho)')>,
#  ('Cassava Chips (dry)', None, None, None): <Commodity(id=51, name='Cassava Chips (dry)')>,
#  ('Cassava Fresh', None, None, None): <Commodity(id=50, name='Cassava Fresh')>,
#  ('Cat Fish(Mkizi/Fume)', 'Chilled', None, None): <Commodity(id=332, name='Cat Fish(Mkizi/Fume)')>,
#  ('Cat Fish(Mkizi/Fume)', 'Dried', None, None): <Commodity(id=378, name='Cat Fish(Mkizi/Fume)')>,
#  ('Cat Fish(Mkizi/Fume)', None, None, None): <Commodity(id=609, name='Cat Fish(Mkizi/Fume)')>,
#  ('Cat Fish(Mkizi/Fume)', 'Fresh', None, None): <Commodity(id=46, name='Cat Fish(Mkizi/Fume)')>,
#  ('Cat Fish(Mkizi/Fume)', 'Frozen', None, None): <Commodity(id=632, name='Cat Fish(Mkizi/Fume)')>,
#  ('Cat Fish(Mkizi/Fume)', 'Headless and Gutted', None, None): <Commodity(id=405, name='Cat Fish(Mkizi/Fume)')>,
#  ('Cat Fish(Mkizi/Fume)', 'Smoked', None, None): <Commodity(id=317, name='Cat Fish(Mkizi/Fume)')>,
#  ('Cattle', None, 'Grade 2', 'female'): <Commodity(id=216, name='Cattle')>,
#  ('Cattle', 'Ayrshire', None, 'female'): <Commodity(id=186, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 1 ', 'female'): <Commodity(id=275, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 1 ', 'male'): <Commodity(id=329, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 2', 'female'): <Commodity(id=276, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 1 ', 'female'): <Commodity(id=147, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 2', 'female'): <Commodity(id=322, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 2', 'male'): <Commodity(id=296, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 4 ', 'male'): <Commodity(id=308, name='Cattle')>,
#  ('Cattle', 'Mixed', None, 'castrate'): <Commodity(id=215, name='Cattle')>,
#  ('Cattle', 'Mixed', None, 'female'): <Commodity(id=199, name='Cattle')>,
#  ('Cattle', None, None, 'male'): <Commodity(id=207, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 5', 'male'): <Commodity(id=234, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 1 ', 'female'): <Commodity(id=159, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 1 ', 'male'): <Commodity(id=297, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 2', 'female'): <Commodity(id=178, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 2', 'male'): <Commodity(id=197, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 5', 'female'): <Commodity(id=229, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 5', 'male'): <Commodity(id=157, name='Cattle')>,
#  ('Cattle', 'Mixed', None, 'male'): <Commodity(id=156, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 1 ', 'female'): <Commodity(id=170, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 5', 'male'): <Commodity(id=169, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 1 ', 'male'): <Commodity(id=290, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 2', 'male'): <Commodity(id=289, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 1 ', 'female'): <Commodity(id=182, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 1 ', 'male'): <Commodity(id=288, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 3 ', 'male'): <Commodity(id=153, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 4 ', 'female'): <Commodity(id=155, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 4 ', 'male'): <Commodity(id=154, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 5', 'female'): <Commodity(id=177, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 5', 'male'): <Commodity(id=176, name='Cattle')>,
#  ('Cattle', None, 'Grade 1 ', 'female'): <Commodity(id=307, name='Cattle')>,
#  ('Cattle', None, 'Grade 1 ', 'male'): <Commodity(id=299, name='Cattle')>,
#  ('Cattle', None, 'Grade 2', 'male'): <Commodity(id=303, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 2', 'castrate'): <Commodity(id=503, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 2', 'male'): <Commodity(id=476, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 3 ', 'castrate'): <Commodity(id=514, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 4 ', 'female'): <Commodity(id=318, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 4 ', 'male'): <Commodity(id=658, name='Cattle')>,
#  ('Cattle', 'Ayrshire', None, 'male'): <Commodity(id=706, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 1 ', 'castrate'): <Commodity(id=620, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 2', 'castrate'): <Commodity(id=581, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 3 ', 'castrate'): <Commodity(id=601, name='Cattle')>,
#  ('Cattle', 'Exotic', 'Grade 2', 'female'): <Commodity(id=488, name='Cattle')>,
#  ('Cattle', 'Exotic', 'Grade 2', 'male'): <Commodity(id=526, name='Cattle')>,
#  ('Cattle', 'Exotic', 'Grade 3 ', 'female'): <Commodity(id=627, name='Cattle')>,
#  ('Cattle', 'Exotic', 'Grade 4 ', 'female'): <Commodity(id=544, name='Cattle')>,
#  ('Cattle', 'Exotic', 'Grade 4 ', 'male'): <Commodity(id=535, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 1 ', 'female'): <Commodity(id=321, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 1 ', 'male'): <Commodity(id=328, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 2', 'castrate'): <Commodity(id=507, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 2', 'male'): <Commodity(id=486, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 3 ', 'castrate'): <Commodity(id=518, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 3 ', 'female'): <Commodity(id=479, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 3 ', 'male'): <Commodity(id=477, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 4 ', 'castrate'): <Commodity(id=478, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 4 ', 'female'): <Commodity(id=520, name='Cattle')>,
#  ('Cattle', 'Friesian', None, 'male'): <Commodity(id=705, name='Cattle')>,
#  ('Cattle', 'Guernsey ', 'Grade 1 ', 'female'): <Commodity(id=633, name='Cattle')>,
#  ('Cattle', 'Guernsey ', 'Grade 1 ', 'male'): <Commodity(id=469, name='Cattle')>,
#  ('Cattle', 'Guernsey ', 'Grade 2', 'female'): <Commodity(id=505, name='Cattle')>,
#  ('Cattle', 'Guernsey ', 'Grade 2', 'male'): <Commodity(id=582, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 1 ', 'castrate'): <Commodity(id=618, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 2', 'castrate'): <Commodity(id=617, name='Cattle')>,
#  ('Cattle', None, 'Grade 3 ', 'castrate'): <Commodity(id=622, name='Cattle')>,
#  ('Cattle', 'Guernsey ', 'Grade 3 ', 'female'): <Commodity(id=645, name='Cattle')>,
#  ('Cattle', 'Guernsey ', 'Grade 3 ', 'male'): <Commodity(id=497, name='Cattle')>,
#  ('Cattle', 'Guernsey ', 'Grade 4 ', 'female'): <Commodity(id=482, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 1 ', 'castrate'): <Commodity(id=354, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 3 ', 'castrate'): <Commodity(id=602, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 3 ', 'female'): <Commodity(id=325, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 3 ', 'male'): <Commodity(id=319, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 4 ', 'male'): <Commodity(id=509, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 1 ', 'male'): <Commodity(id=309, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 3 ', 'castrate'): <Commodity(id=659, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 3 ', 'female'): <Commodity(id=563, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 3 ', 'male'): <Commodity(id=564, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 4 ', 'female'): <Commodity(id=699, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 4 ', 'male'): <Commodity(id=661, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 2', 'castrate'): <Commodity(id=588, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 3 ', 'castrate'): <Commodity(id=504, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 3 ', 'female'): <Commodity(id=502, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 4 ', 'female'): <Commodity(id=489, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 4 ', 'male'): <Commodity(id=487, name='Cattle')>,
#  ('Cattle', 'Sahiwal', None, 'castrate'): <Commodity(id=491, name='Cattle')>,
#  ('Cattle', 'Sahiwal', None, 'male'): <Commodity(id=510, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 4 ', 'castrate'): <Commodity(id=708, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 1 ', 'male'): <Commodity(id=578, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 2', 'castrate'): <Commodity(id=597, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 2', 'female'): <Commodity(id=598, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 2', 'male'): <Commodity(id=599, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 3 ', 'castrate'): <Commodity(id=686, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 3 ', 'female'): <Commodity(id=600, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 3 ', 'male'): <Commodity(id=585, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 1 ', 'castrate'): <Commodity(id=532, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 2', 'castrate'): <Commodity(id=310, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 3 ', 'castrate'): <Commodity(id=499, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 4 ', 'castrate'): <Commodity(id=513, name='Cattle')>,
#  ('Cattle', None, 'Grade 1 ', 'castrate'): <Commodity(id=700, name='Cattle')>,
#  ('Cattle', None, 'Grade 2', 'castrate'): <Commodity(id=561, name='Cattle')>,
#  ('Cattle', None, 'Grade 3 ', 'female'): <Commodity(id=326, name='Cattle')>,
#  ('Cattle', None, 'Grade 3 ', 'male'): <Commodity(id=327, name='Cattle')>,
#  ('Cattle', None, 'Grade 4 ', 'female'): <Commodity(id=536, name='Cattle')>,
#  ('Cattle', None, 'Grade 4 ', 'male'): <Commodity(id=537, name='Cattle')>,
#  ('Cattle', 'Boran', None, 'female'): <Commodity(id=716, name='Cattle')>,
#  ('Cattle', 'Exotic', None, 'female'): <Commodity(id=753, name='Cattle')>,
#  ('Cattle', 'Sahiwal', None, 'female'): <Commodity(id=746, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 4 ', 'castrate'): <Commodity(id=741, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 4 ', 'male'): <Commodity(id=715, name='Cattle')>,
#  ('Cattle', None, None, 'female'): <Commodity(id=719, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 1 ', 'castrate'): <Commodity(id=774, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 3 ', 'female'): <Commodity(id=374, name='Cattle')>,
#  ('Cattle', 'Ayrshire', 'Grade 3 ', 'male'): <Commodity(id=367, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 4 ', 'female'): <Commodity(id=397, name='Cattle')>,
#  ('Cattle', 'Exotic', 'Grade 1 ', 'female'): <Commodity(id=379, name='Cattle')>,
#  ('Cattle', 'Exotic', 'Grade 1 ', 'male'): <Commodity(id=380, name='Cattle')>,
#  ('Cattle', 'Exotic', 'Grade 3 ', 'male'): <Commodity(id=375, name='Cattle')>,
#  ('Cattle', 'Exotic', None, 'male'): <Commodity(id=763, name='Cattle')>,
#  ('Cattle', 'Friesian', None, 'female'): <Commodity(id=557, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 1 ', 'castrate'): <Commodity(id=769, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 2', 'female'): <Commodity(id=387, name='Cattle')>,
#  ('Cattle', 'Friesian', 'Grade 4 ', 'male'): <Commodity(id=792, name='Cattle')>,
#  ('Cattle', 'Gabra/Redille', 'Grade 1 ', 'male'): <Commodity(id=777, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 2', 'castrate'): <Commodity(id=377, name='Cattle')>,
#  ('Cattle', 'Mixed', 'Grade 4 ', 'female'): <Commodity(id=336, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 2', 'female'): <Commodity(id=559, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 2', 'male'): <Commodity(id=560, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 1 ', 'castrate'): <Commodity(id=365, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 1 ', 'female'): <Commodity(id=363, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 2', 'female'): <Commodity(id=364, name='Cattle')>,
#  ('Cattle', 'Sahiwal', 'Grade 3 ', 'male'): <Commodity(id=396, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 1 ', 'female'): <Commodity(id=784, name='Cattle')>,
#  ('Cattle', 'Somali spotted', 'Grade 4 ', 'female'): <Commodity(id=714, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 1', 'female'): <Commodity(id=721, name='Cattle')>,
#  ('Cattle', None, 'Grade 4 ', 'castrate'): <Commodity(id=799, name='Cattle')>,
#  ('Cattle', None, 'Grade 5', 'male'): <Commodity(id=115, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 1 ', 'male'): <Commodity(id=47, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 3 ', 'female'): <Commodity(id=103, name='Cattle')>,
#  ('Cattle', 'Boran', 'Grade 3 ', 'male'): <Commodity(id=102, name='Cattle')>,
#  ('Cattle', 'Boran', None, 'male'): <Commodity(id=45, name='Cattle')>,
#  ('Cattle', 'Other', None, 'male'): <Commodity(id=24, name='Cattle')>,
#  ('Cattle', 'Other', 'Grade 5', 'female'): <Commodity(id=21, name='Cattle')>,
#  ('Cattle', 'Other', None, 'female'): <Commodity(id=20, name='Cattle')>,
#  ('Cattle', 'Zebu', None, 'male'): <Commodity(id=31, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 3 ', 'female'): <Commodity(id=29, name='Cattle')>,
#  ('Cattle', 'Zebu', None, 'female'): <Commodity(id=27, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 2', 'female'): <Commodity(id=25, name='Cattle')>,
#  ('Cattle', 'Zebu', 'Grade 2', 'male'): <Commodity(id=44, name='Cattle')>,
#  ('Cattle Hide', None, 'Grade 1', None): <Commodity(id=206, name='Cattle Hide')>,
#  ('Cattle Hide', None, 'Grade 2', None): <Commodity(id=608, name='Cattle Hide')>,
#  ('Cattle Hide', None, 'Grade 3', None): <Commodity(id=286, name='Cattle Hide')>,
#  ('Cattle Hide', None, 'Grade 4', None): <Commodity(id=524, name='Cattle Hide')>,
#  ('Cattle Hide', None, 'Grade 5 Reject', None): <Commodity(id=782, name='Cattle Hide')>,
#  ('Cauliflower', None, None, None): <Commodity(id=137, name='Cauliflower')>,
#  ('Chicken', 'Indigenous', None, 'castrate'): <Commodity(id=493, name='Chicken')>,
#  ('Chicken', None, None, 'female'): <Commodity(id=579, name='Chicken')>,
#  ('Chicken', None, None, 'male'): <Commodity(id=666, name='Chicken')>,
#  ('Chicken', 'Ayrshire', None, 'female'): <Commodity(id=675, name='Chicken')>,
#  ('Chicken', 'Ayrshire', None, 'male'): <Commodity(id=797, name='Chicken')>,
#  ('Chicken', 'Boran', None, 'female'): <Commodity(id=795, name='Chicken')>,
#  ('Chicken', 'Broiler', None, 'castrate'): <Commodity(id=768, name='Chicken')>,
#  ('Chicken', 'Broiler', None, 'female'): <Commodity(id=313, name='Chicken')>,
#  ('Chicken', 'Broiler', None, 'male'): <Commodity(id=116, name='Chicken')>,
#  ('Chicken', 'Hamshire', None, 'female'): <Commodity(id=806, name='Chicken')>,
#  ('Chicken', 'Improved Kienyeji', None, 'castrate'): <Commodity(id=160, name='Chicken')>,
#  ('Chicken', 'Improved Kienyeji', None, 'female'): <Commodity(id=9, name='Chicken')>,
#  ('Chicken', 'Improved Kienyeji', None, 'male'): <Commodity(id=8, name='Chicken')>,
#  ('Chicken', 'Indigenous', None, 'female'): <Commodity(id=13, name='Chicken')>,
#  ('Chicken', 'Indigenous', None, 'male'): <Commodity(id=16, name='Chicken')>,
#  ('Chicken', 'Layers', None, 'female'): <Commodity(id=320, name='Chicken')>,
#  ('Chicken', 'Layers', None, 'male'): <Commodity(id=306, name='Chicken')>,
#  ('Chicken', 'Mallard', None, 'male'): <Commodity(id=738, name='Chicken')>,
#  ('Chillies', None, None, None): <Commodity(id=111, name='Chillies')>,
#  ('Coconut', None, None, None): <Commodity(id=779, name='Coconut')>,
#  ('Coconut Oil', None, None, None): <Commodity(id=300, name='Coconut Oil')>,
#  ('Coffee', None, None, None): <Commodity(id=621, name='Coffee')>,
#  ('Common Carp', 'Dried', None, None): <Commodity(id=381, name='Common Carp')>,
#  ('Common Carp', 'Fresh', None, None): <Commodity(id=208, name='Common Carp')>,
#  ('Common Carp', 'Fried', None, None): <Commodity(id=472, name='Common Carp')>,
#  ('Common Carp', 'Frozen/Chilled', None, None): <Commodity(id=747, name='Common Carp')>,
#  ('Coriander (Dhania)', None, None, None): <Commodity(id=91, name='Coriander (Dhania)')>,
#  ('Cotton', None, None, None): <Commodity(id=649, name='Cotton')>,
#  ('Cotton Seed', None, None, None): <Commodity(id=590, name='Cotton Seed')>,
#  ('Courgette', None, None, None): <Commodity(id=128, name='Courgette')>,
#  ('Cow Milk(At collection point)', None, None, 'male'): <Commodity(id=231, name='Cow Milk(At collection point)')>,
#  ('Cow Milk(At collection point)', None, None, None): <Commodity(id=33, name='Cow Milk(At collection point)')>,
#  ('Cow Milk(Processd)', None, None, None): <Commodity(id=32, name='Cow Milk(Processd)')>,
#  ('Cowpea leaves (Kunde)', None, None, 'male'): <Commodity(id=238, name='Cowpea leaves (Kunde)')>,
#  ('Cowpea leaves (Kunde)', None, None, None): <Commodity(id=70, name='Cowpea leaves (Kunde)')>,
#  ('Cowpeas', None, None, 'male'): <Commodity(id=265, name='Cowpeas')>,
#  ('Cowpeas', None, None, None): <Commodity(id=80, name='Cowpeas')>,
#  ('Cucumber', None, None, None): <Commodity(id=130, name='Cucumber')>,
#  ('Cuttlefish', 'Dried', None, None): <Commodity(id=654, name='Cuttlefish')>,
#  ('Cuttlefish', 'Fresh', None, None): <Commodity(id=761, name='Cuttlefish')>,
#  ('Dolichos lablab (Njahi)', None, None, 'male'): <Commodity(id=263, name='Dolichos lablab (Njahi)')>,
#  ('Dolichos lablab (Njahi)', None, None, None): <Commodity(id=119, name='Dolichos lablab (Njahi)')>,
#  ('Donkey', None, None, 'castrate'): <Commodity(id=596, name='Donkey')>,
#  ('Donkey', None, None, 'female'): <Commodity(id=10, name='Donkey')>,
#  ('Donkey', None, None, 'male'): <Commodity(id=11, name='Donkey')>,
#  ('Dragon Fruit', None, None, None): <Commodity(id=804, name='Dragon Fruit')>,
#  ('Dry Maize', 'Mixed-Traditional ', None, 'male'): <Commodity(id=235, name='Dry Maize')>,
#  ('Dry Maize', None, None, None): <Commodity(id=282, name='Dry Maize')>,
#  ('Dry Maize', None, None, 'male'): <Commodity(id=400, name='Dry Maize')>,
#  ('Dry Maize', 'IRR', None, None): <Commodity(id=788, name='Dry Maize')>,
#  ('Dry Maize', 'Mixed-Traditional ', None, None): <Commodity(id=66, name='Dry Maize')>,
#  ('Dry Maize', 'White Maize', None, None): <Commodity(id=65, name='Dry Maize')>,
#  ('Dry Maize', 'Yellow Maize', None, None): <Commodity(id=64, name='Dry Maize')>,
#  ('Dry Onions', None, None, 'male'): <Commodity(id=247, name='Dry Onions')>,
#  ('Dry Onions', None, None, None): <Commodity(id=93, name='Dry Onions')>,
#  ('Dry Peas', None, None, None): <Commodity(id=109, name='Dry Peas')>,
#  ('Duck', 'Black Swedish', 'Grade 1', 'female'): <Commodity(id=468, name='Duck')>,
#  ('Duck', 'Black Swedish', 'Grade 1', 'male'): <Commodity(id=521, name='Duck')>,
#  ('Duck', 'Black Swedish', 'Grade 2', 'female'): <Commodity(id=292, name='Duck')>,
#  ('Duck', 'Black Swedish', 'Grade 2', 'male'): <Commodity(id=293, name='Duck')>,
#  ('Duck', 'Khaki Campbell', 'Grade 1', 'female'): <Commodity(id=395, name='Duck')>,
#  ('Duck', 'Khaki Campbell', 'Grade 1', 'male'): <Commodity(id=394, name='Duck')>,
#  ('Duck', 'Khaki Campbell', 'Grade 2', 'female'): <Commodity(id=357, name='Duck')>,
#  ('Duck', 'Khaki Campbell', 'Grade 2', 'male'): <Commodity(id=358, name='Duck')>,
#  ('Duck', 'Mallard', 'Grade 1', 'male'): <Commodity(id=759, name='Duck')>,
#  ('Duck', 'Mallard', 'Grade 2', 'female'): <Commodity(id=707, name='Duck')>,
#  ('Duck', 'Mallard', 'Grade 2', 'male'): <Commodity(id=798, name='Duck')>,
#  ('Duck', 'Muscovy', 'Grade 1', 'female'): <Commodity(id=720, name='Duck')>,
#  ('Duck', 'Muscovy', 'Grade 1', 'male'): <Commodity(id=740, name='Duck')>,
#  ('Duck', 'Muscovy', 'Grade 2', 'female'): <Commodity(id=647, name='Duck')>,
#  ('Duck', 'Muscovy', 'Grade 2', 'male'): <Commodity(id=648, name='Duck')>,
#  ('Duck', 'Pekin', 'Grade 1', 'castrate'): <Commodity(id=492, name='Duck')>,
#  ('Duck', 'Pekin', 'Grade 1', 'female'): <Commodity(id=466, name='Duck')>,
#  ('Duck', 'Pekin', 'Grade 1', 'male'): <Commodity(id=522, name='Duck')>,
#  ('Duck', 'Pekin', 'Grade 2', 'castrate'): <Commodity(id=687, name='Duck')>,
#  ('Duck', 'Pekin', 'Grade 2', 'female'): <Commodity(id=684, name='Duck')>,
#  ('Duck', 'Pekin', 'Grade 2', 'male'): <Commodity(id=688, name='Duck')>,
#  ('Eel\t', 'Dried', None, None): <Commodity(id=765, name='Eel	')>,
#  ('Egg plant (Brinjals)', None, None, None): <Commodity(id=131, name='Egg plant (Brinjals)')>,
#  ('Eggs', 'Exotic/Grade', None, None): <Commodity(id=30, name='Eggs')>,
#  ('Eggs', 'Indigenous /Kenyeji', None, None): <Commodity(id=144, name='Eggs')>,
#  ('Eggs', 'Indigenous /Kenyeji', None, 'male'): <Commodity(id=232, name='Eggs')>,
#  ('Ethiopian Kales -Kanzira', None, None, None): <Commodity(id=138, name='Ethiopian Kales -Kanzira')>,
#  ('Fertilizer', 'Ammonia Anhydrous', None, None): <Commodity(id=807, name='Fertilizer')>,
#  ('Fertilizer', 'CAN', None, 'male'): <Commodity(id=278, name='Fertilizer')>,
#  ('Fertilizer', 'CAN', None, None): <Commodity(id=5, name='Fertilizer')>,
#  ('Fertilizer', 'DAP', None, None): <Commodity(id=4, name='Fertilizer')>,
#  ('Fertilizer', 'NPK', None, None): <Commodity(id=3, name='Fertilizer')>,
#  ('Fertilizer', 'Sulphate of Ammonia', None, None): <Commodity(id=802, name='Fertilizer')>,
#  ('Fertilizer', 'Urea', None, None): <Commodity(id=801, name='Fertilizer')>,
#  ('Finger Millet', None, None, 'male'): <Commodity(id=236, name='Finger Millet')>,
#  ('Finger Millet', None, None, None): <Commodity(id=63, name='Finger Millet')>,
#  ('Fish Maws', None, None, None): <Commodity(id=631, name='Fish Maws')>,
#  ('Fish Oil', None, None, None): <Commodity(id=528, name='Fish Oil')>,
#  ('Fish Scales', None, None, None): <Commodity(id=543, name='Fish Scales')>,
#  ('French beans', None, None, None): <Commodity(id=132, name='French beans')>,
#  ('Fresh Peas', 'On pods', None, None): <Commodity(id=101, name='Fresh Peas')>,
#  ('Fresh Peas', 'Shelled Peas', None, None): <Commodity(id=285, name='Fresh Peas')>,
#  ('Fresh Water Shrimp', 'Dried', None, None): <Commodity(id=356, name='Fresh Water Shrimp')>,
#  ('Fresh Water Shrimp', 'Fresh', None, None): <Commodity(id=385, name='Fresh Water Shrimp')>,
#  ('Garlic', None, None, None): <Commodity(id=92, name='Garlic')>,
#  ('Ginger', None, None, 'male'): <Commodity(id=256, name='Ginger')>,
#  ('Ginger', None, None, None): <Commodity(id=78, name='Ginger')>,
#  ('Goat', 'Dairy Goats', 'Grade 2 ', 'castrate'): <Commodity(id=660, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 1 ', 'castrate'): <Commodity(id=615, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 3  ', 'castrate'): <Commodity(id=635, name='Goat')>,
#  ('Goat', None, 'Grade 2 ', 'male'): <Commodity(id=680, name='Goat')>,
#  ('Goat', 'Dairy Goats', None, 'male'): <Commodity(id=683, name='Goat')>,
#  ('Goat', None, None, 'female'): <Commodity(id=696, name='Goat')>,
#  ('Goat', None, None, 'male'): <Commodity(id=411, name='Goat')>,
#  ('Goat', 'Black Swedish', None, 'female'): <Commodity(id=723, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 1 ', 'castrate'): <Commodity(id=739, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 1 ', 'female'): <Commodity(id=312, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 2 ', 'female'): <Commodity(id=324, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 2 ', 'male'): <Commodity(id=192, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 1 ', 'female'): <Commodity(id=171, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 2 ', 'female'): <Commodity(id=161, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 2 ', 'male'): <Commodity(id=193, name='Goat')>,
#  ('Goat', 'East African Goat', None, 'castrate'): <Commodity(id=273, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 1 ', 'male'): <Commodity(id=291, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 3  ', 'female'): <Commodity(id=105, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 3  ', 'male'): <Commodity(id=104, name='Goat')>,
#  ('Goat', 'East African Goat', None, 'female'): <Commodity(id=6, name='Goat')>,
#  ('Goat', 'East African Goat', None, 'male'): <Commodity(id=7, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 1 ', 'female'): <Commodity(id=146, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 1 ', 'male'): <Commodity(id=298, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 2 ', 'female'): <Commodity(id=212, name='Goat')>,
#  ('Goat', 'Galla', None, 'female'): <Commodity(id=211, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 2 ', 'male'): <Commodity(id=210, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 3  ', 'female'): <Commodity(id=213, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 3  ', 'male'): <Commodity(id=330, name='Goat')>,
#  ('Goat', 'Improved Kienyeji', 'Grade 2 ', 'male'): <Commodity(id=724, name='Goat')>,
#  ('Goat', 'Improved Kienyeji', None, 'male'): <Commodity(id=725, name='Goat')>,
#  ('Goat', None, 'Grade 1 ', 'female'): <Commodity(id=730, name='Goat')>,
#  ('Goat', None, 'Grade 1 ', 'male'): <Commodity(id=340, name='Goat')>,
#  ('Goat', None, 'Grade 2 ', 'female'): <Commodity(id=483, name='Goat')>,
#  ('Goat', None, 'Grade 3  ', 'female'): <Commodity(id=745, name='Goat')>,
#  ('Goat', None, 'Grade 3  ', 'male'): <Commodity(id=727, name='Goat')>,
#  ('Goat', 'Broiler', 'Grade 2 ', 'female'): <Commodity(id=796, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 1 ', 'male'): <Commodity(id=368, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 2', 'female'): <Commodity(id=525, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 3  ', 'female'): <Commodity(id=540, name='Goat')>,
#  ('Goat', 'Dairy Goats', None, 'female'): <Commodity(id=546, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 3  ', 'castrate'): <Commodity(id=712, name='Goat')>,
#  ('Goat', 'Dairy Goats', 'Grade 3  ', 'male'): <Commodity(id=556, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 1 ', 'castrate'): <Commodity(id=362, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 2 ', 'castrate'): <Commodity(id=361, name='Goat')>,
#  ('Goat', 'East African Goat', 'Grade 3  ', 'castrate'): <Commodity(id=373, name='Goat')>,
#  ('Goat', 'Gabra/Redille', 'Grade 1 ', 'male'): <Commodity(id=781, name='Goat')>,
#  ('Goat', 'Galla', 'Grade 2 ', 'castrate'): <Commodity(id=595, name='Goat')>,
#  ('Goat', 'Galla', None, 'male'): <Commodity(id=41, name='Goat')>,
#  ('Goat', 'Layers', 'Grade 2 ', 'male'): <Commodity(id=785, name='Goat')>,
#  ('Goat', 'Merino', 'Grade 2 ', 'female'): <Commodity(id=764, name='Goat')>,
#  ('Goat', 'Mixed', None, 'female'): <Commodity(id=187, name='Goat')>,
#  ('Goat', 'Mixed', None, 'male'): <Commodity(id=162, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 1 ', 'castrate'): <Commodity(id=566, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 1 ', 'female'): <Commodity(id=14, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 1 ', 'male'): <Commodity(id=17, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 2 ', 'castrate'): <Commodity(id=529, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 2 ', 'female'): <Commodity(id=12, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 2 ', 'male'): <Commodity(id=15, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 3  ', 'castrate'): <Commodity(id=490, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 3  ', 'female'): <Commodity(id=342, name='Goat')>,
#  ('Goat', 'Mixed', 'Grade 3  ', 'male'): <Commodity(id=366, name='Goat')>,
#  ('Goat Milk (at collection point)', None, None, None): <Commodity(id=34, name='Goat Milk (at collection point)')>,
#  ('Goat Skin', None, 'Grade 1', None): <Commodity(id=495, name='Goat Skin')>,
#  ('Goat Skin', None, 'Grade 2', None): <Commodity(id=587, name='Goat Skin')>,
#  ('Goat Skin', None, 'Grade 3', None): <Commodity(id=574, name='Goat Skin')>,
#  ('Goat Skin', None, 'Grade 4', None): <Commodity(id=523, name='Goat Skin')>,
#  ('Goat Skin', None, 'Grade 5 Reject', None): <Commodity(id=575, name='Goat Skin')>,
#  ('Goat milk (Processed)', None, None, None): <Commodity(id=591, name='Goat milk (Processed)')>,
#  ('Goatfishes', 'Dried', None, None): <Commodity(id=786, name='Goatfishes')>,
#  ('Goatfishes', 'Fresh', None, None): <Commodity(id=508, name='Goatfishes')>,
#  ('Goatfishes', 'Frozen/Chilled', None, None): <Commodity(id=663, name='Goatfishes')>,
#  ('Golden (Deep-Sea) Crabs Kaa', 'Dried', None, None): <Commodity(id=655, name='Golden (Deep-Sea) Crabs Kaa')>,
#  ('Golden (Deep-Sea) Crabs Kaa', 'Fresh', None, None): <Commodity(id=773, name='Golden (Deep-Sea) Crabs Kaa')>,
#  ('Grapes', 'Black-Dark', None, None): <Commodity(id=185, name='Grapes')>,
#  ('Grapes', 'Red', None, None): <Commodity(id=284, name='Grapes')>,
#  ('Grapes', 'White', None, None): <Commodity(id=545, name='Grapes')>,
#  ('Green Grams', 'Hybrid/ polished', None, 'male'): <Commodity(id=259, name='Green Grams')>,
#  ('Green Grams', 'Hybrid/ polished', None, None): <Commodity(id=88, name='Green Grams')>,
#  ('Green Grams', 'Local-Special', None, None): <Commodity(id=87, name='Green Grams')>,
#  ('Green Grams', 'Makueni', None, None): <Commodity(id=85, name='Green Grams')>,
#  ('Green Grams', 'Small Red', None, None): <Commodity(id=776, name='Green Grams')>,
#  ('Green Maize', None, None, None): <Commodity(id=77, name='Green Maize')>,
#  ('Ground Nuts', None, None, None): <Commodity(id=718, name='Ground Nuts')>,
#  ('Ground Nuts', 'Hybrid/ polished', None, None): <Commodity(id=787, name='Ground Nuts')>,
#  ('Ground Nuts', 'Large Brown', None, None): <Commodity(id=83, name='Ground Nuts')>,
#  ('Ground Nuts', 'Small Red', None, None): <Commodity(id=84, name='Ground Nuts')>,
#  ('Groupers', 'Dried', None, None): <Commodity(id=640, name='Groupers')>,
#  ('Groupers', 'Fresh', None, None): <Commodity(id=353, name='Groupers')>,
#  ('Grunt(Taamamba/Kora)', 'Dried', None, None): <Commodity(id=359, name='Grunt(Taamamba/Kora)')>,
#  ('Grunt(Taamamba/Kora)', 'Fresh', None, None): <Commodity(id=205, name='Grunt(Taamamba/Kora)')>,
#  ('Halfbeaks', 'Dried', None, None): <Commodity(id=652, name='Halfbeaks')>,
#  ('Halfbeaks', 'Fresh', None, None): <Commodity(id=685, name='Halfbeaks')>,
#  ('Haplochromis', 'Dried', None, None): <Commodity(id=305, name='Haplochromis')>,
#  ('Haplochromis', 'Fresh', None, None): <Commodity(id=189, name='Haplochromis')>,
#  ('Haplochromis', 'Smoked', None, None): <Commodity(id=407, name='Haplochromis')>,
#  ('Honey', 'Crude', None, None): <Commodity(id=145, name='Honey')>,
#  ('Honey', 'Processed', None, None): <Commodity(id=164, name='Honey')>,
#  ('Indigenous Crotolaria (Mito/Miro)', None, None, None): <Commodity(id=69, name='Indigenous Crotolaria (Mito/Miro)')>,
#  ('Jacks/Trevallies(Kolekole)', 'Dried', None, None): <Commodity(id=630, name='Jacks/Trevallies(Kolekole)')>,
#  ('Jacks/Trevallies(Kolekole)', 'Fresh', None, None): <Commodity(id=352, name='Jacks/Trevallies(Kolekole)')>,
#  ('Jacks/Trevallies(Kolekole)', 'Frozen/Chilled', None, None): <Commodity(id=613, name='Jacks/Trevallies(Kolekole)')>,
#  ('Jobfish', 'Dried', None, None): <Commodity(id=678, name='Jobfish')>,
#  ('Jobfish', 'Fresh', None, None): <Commodity(id=690, name='Jobfish')>,
#  ('Jute Plant (Murenda)', None, None, None): <Commodity(id=68, name='Jute Plant (Murenda)')>,
#  ('Kales/Sukuma Wiki', None, None, 'male'): <Commodity(id=251, name='Kales/Sukuma Wiki')>,
#  ('Kales/Sukuma Wiki', None, None, None): <Commodity(id=76, name='Kales/Sukuma Wiki')>,
#  ('Kingfish (Nguru)', 'Dried', None, None): <Commodity(id=481, name='Kingfish (Nguru)')>,
#  ('Kingfish (Nguru)', 'Fresh', None, None): <Commodity(id=614, name='Kingfish (Nguru)')>,
#  ('Kingfish (Nguru)', 'Frozen/Chilled', None, None): <Commodity(id=351, name='Kingfish (Nguru)')>,
#  ('Labeo', 'Dried', None, None): <Commodity(id=624, name='Labeo')>,
#  ('Labeo', 'Fresh', None, None): <Commodity(id=355, name='Labeo')>,
#  ('Labeo', 'Frozen/Chilled', None, None): <Commodity(id=789, name='Labeo')>,
#  ('Labeo', 'Smoked', None, None): <Commodity(id=771, name='Labeo')>,
#  ('Lemons', None, None, None): <Commodity(id=113, name='Lemons')>,
#  ('Lentils', None, None, None): <Commodity(id=121, name='Lentils')>,
#  ('Lettuce', None, None, None): <Commodity(id=133, name='Lettuce')>,
#  ('Limes', None, None, None): <Commodity(id=141, name='Limes')>,
#  ('Lobster(Kamba Mawe)', 'Dried', None, None): <Commodity(id=388, name='Lobster(Kamba Mawe)')>,
#  ('Lobster(Kamba Mawe)', 'Fried', None, None): <Commodity(id=386, name='Lobster(Kamba Mawe)')>,
#  ('Lobster(Kamba Mawe)', 'Live', None, None): <Commodity(id=610, name='Lobster(Kamba Mawe)')>,
#  ('Macadamia Seed', None, None, None): <Commodity(id=173, name='Macadamia Seed')>,
#  ('Mackerel', 'Dried', None, None): <Commodity(id=791, name='Mackerel')>,
#  ('Mackerel', 'Fresh', None, None): <Commodity(id=333, name='Mackerel')>,
#  ('Mackerel', 'Frozen/Chilled', None, None): <Commodity(id=516, name='Mackerel')>,
#  ('Maize Bran', None, None, None): <Commodity(id=175, name='Maize Bran')>,
#  ('Maize Flour', '210(two ten)', None, None): <Commodity(id=465, name='Maize Flour')>,
#  ('Maize Flour', 'Ajab', None, None): <Commodity(id=134, name='Maize Flour')>,
#  ('Maize Flour', 'Amaize', None, None): <Commodity(id=372, name='Maize Flour')>,
#  ('Maize Flour', 'Canna', None, None): <Commodity(id=464, name='Maize Flour')>,
#  ('Maize Flour', 'Cosmo', None, None): <Commodity(id=463, name='Maize Flour')>,
#  ('Maize Flour', 'Dola', None, None): <Commodity(id=62, name='Maize Flour')>,
#  ('Maize Flour', 'Equatorial afya ugali', None, None): <Commodity(id=462, name='Maize Flour')>,
#  ('Maize Flour', 'Hostess', None, None): <Commodity(id=461, name='Maize Flour')>,
#  ('Maize Flour', 'Jamii', None, None): <Commodity(id=376, name='Maize Flour')>,
#  ('Maize Flour', 'Jembe', None, None): <Commodity(id=460, name='Maize Flour')>,
#  ('Maize Flour', 'Jimbi', None, None): <Commodity(id=371, name='Maize Flour')>,
#  ('Maize Flour', 'Jogoo', None, None): <Commodity(id=149, name='Maize Flour')>,
#  ('Maize Flour', 'Jogoo wimbi', None, None): <Commodity(id=459, name='Maize Flour')>,
#  ('Maize Flour', 'Kifaru', None, None): <Commodity(id=458, name='Maize Flour')>,
#  ('Maize Flour', 'Ndovu', None, None): <Commodity(id=457, name='Maize Flour')>,
#  ('Maize Flour', 'Organic ( millet, sorghum & maize flour )', None, None): <Commodity(id=454, name='Maize Flour')>,
#  ('Maize Flour', 'Organic (cassava, sorghum &maize)', None, None): <Commodity(id=455, name='Maize Flour')>,
#  ('Maize Flour', 'Organic (maize&cassava flour)', None, None): <Commodity(id=456, name='Maize Flour')>,
#  ('Maize Flour', 'Oryx', None, None): <Commodity(id=453, name='Maize Flour')>,
#  ('Maize Flour', 'Shujaa', None, None): <Commodity(id=452, name='Maize Flour')>,
#  ('Maize Flour', 'Soko', None, None): <Commodity(id=447, name='Maize Flour')>,
#  ('Maize Flour', 'Taifa', None, None): <Commodity(id=451, name='Maize Flour')>,
#  ('Maize Flour', 'Tajiri maize meal', None, None): <Commodity(id=450, name='Maize Flour')>,
#  ('Maize Flour', 'Twiga', None, None): <Commodity(id=449, name='Maize Flour')>,
#  ('Maize Flour', 'Unga afya', None, None): <Commodity(id=448, name='Maize Flour')>,
#  ('Maize Flour', None, None, None): <Commodity(id=470, name='Maize Flour')>,
#  ('Maize Flour', 'Kiki maize meal', None, None): <Commodity(id=474, name='Maize Flour')>,
#  ('Maize Flour', 'Mama', None, None): <Commodity(id=204, name='Maize Flour')>,
#  ('Maize Flour', 'Pembe', None, None): <Commodity(id=301, name='Maize Flour')>,
#  ('Maize Flour', 'Posho Mill ', None, None): <Commodity(id=214, name='Maize Flour')>,
#  ('Maize Flour', 'Raha Premium', None, None): <Commodity(id=370, name='Maize Flour')>,
#  ('Maize Flour', 'Supreme', None, None): <Commodity(id=473, name='Maize Flour')>,
#  ('Maize Flour', 'Ugali Afya', None, None): <Commodity(id=142, name='Maize Flour')>,
#  ('Mangoes', 'Improved', None, None): <Commodity(id=401, name='Mangoes')>,
#  ('Mangoes', 'Local', None, None): <Commodity(id=399, name='Mangoes')>,
#  ('Mangoes', None, None, None): <Commodity(id=56, name='Mangoes')>,
#  ('Mangoes Local', None, None, None): <Commodity(id=55, name='Mangoes Local')>,
#  ('Marlins', 'Dried', None, None): <Commodity(id=656, name='Marlins')>,
#  ('Marlins', 'Fresh', None, None): <Commodity(id=625, name='Marlins')>,
#  ('Marlins', 'Frozen/Chilled', None, None): <Commodity(id=760, name='Marlins')>,
#  ('Meat Beef', None, None, None): <Commodity(id=28, name='Meat Beef')>,
#  ('Meat Broiler', None, None, None): <Commodity(id=165, name='Meat Broiler')>,
#  ('Meat Chevon', None, None, None): <Commodity(id=143, name='Meat Chevon')>,
#  ('Meat Chevon', None, None, 'male'): <Commodity(id=233, name='Meat Chevon')>,
#  ('Meat Indiginous Chicken', None, None, None): <Commodity(id=166, name='Meat Indiginous Chicken')>,
#  ('Meat Mutton', None, None, None): <Commodity(id=167, name='Meat Mutton')>,
#  ('Mixed Beans', None, None, None): <Commodity(id=151, name='Mixed Beans')>,
#  ('Mixed Demersal', 'Dried', None, None): <Commodity(id=677, name='Mixed Demersal')>,
#  ('Mixed Demersal', 'Fresh', None, None): <Commodity(id=338, name='Mixed Demersal')>,
#  ('Mixed Pelagics', 'Fresh', None, None): <Commodity(id=506, name='Mixed Pelagics')>,
#  ('Mormyrus', 'Dried', None, None): <Commodity(id=657, name='Mormyrus')>,
#  ('Mormyrus', 'Fresh', None, None): <Commodity(id=644, name='Mormyrus')>,
#  ('Mud Crabs', 'Dried', None, None): <Commodity(id=651, name='Mud Crabs')>,
#  ('Mud Crabs', 'Fresh', None, None): <Commodity(id=668, name='Mud Crabs')>,
#  ('Mullets(Fumi)', 'Dried', None, None): <Commodity(id=671, name='Mullets(Fumi)')>,
#  ('Mullets(Fumi)', 'Fresh', None, None): <Commodity(id=704, name='Mullets(Fumi)')>,
#  ('Mullets(Fumi)', 'Frozen/Chilled', None, None): <Commodity(id=571, name='Mullets(Fumi)')>,
#  ('Nderema- Vine Spinach', None, None, None): <Commodity(id=148, name='Nderema- Vine Spinach')>,
#  ('Needlefishes', 'Dried', None, None): <Commodity(id=709, name='Needlefishes')>,
#  ('Needlefishes', 'Fresh', None, None): <Commodity(id=692, name='Needlefishes')>,
#  ('Nile Perch', 'Fillet', None, None): <Commodity(id=209, name='Nile Perch')>,
#  ('Nile Perch', 'Fresh', 'Grade 1', None): <Commodity(id=217, name='Nile Perch')>,
#  ('Nile Perch', 'Fresh', 'Grade 2', None): <Commodity(id=224, name='Nile Perch')>,
#  ('Nile Perch', None, 'Grade 2', None): <Commodity(id=225, name='Nile Perch')>,
#  ('Nile Perch', 'Fresh', None, None): <Commodity(id=43, name='Nile Perch')>,
#  ('Nile Perch', 'Fried', None, None): <Commodity(id=42, name='Nile Perch')>,
#  ('Nile Perch', 'Frozen/Chilled', None, None): <Commodity(id=409, name='Nile Perch')>,
#  ('Nile Perch', 'Smoked', None, None): <Commodity(id=188, name='Nile Perch')>,
#  ('Nile Perch Skins', None, None, None): <Commodity(id=623, name='Nile Perch Skins')>,
#  ('Njugu Mawe', None, None, None): <Commodity(id=203, name='Njugu Mawe')>,
#  ('Octopus (Pweza)', 'Dried', None, None): <Commodity(id=636, name='Octopus (Pweza)')>,
#  ('Octopus (Pweza)', 'Fresh', None, None): <Commodity(id=384, name='Octopus (Pweza)')>,
#  ("Okra (Lady's fingers or Gumbo)", None, None, None): <Commodity(id=780, name='Okra (Lady's fingers or Gumbo)')>,
#  ('Omena', 'Dried', 'Grade 1', None): <Commodity(id=268, name='Omena')>,
#  ('Omena', 'Dried', 'Grade 2', None): <Commodity(id=222, name='Omena')>,
#  ('Omena', 'Dried', None, None): <Commodity(id=39, name='Omena')>,
#  ('Omena', 'Fresh', None, None): <Commodity(id=179, name='Omena')>,
#  ('Omena', 'Fresh', 'Grade 2', None): <Commodity(id=223, name='Omena')>,
#  ('Omena', None, 'Grade 1', None): <Commodity(id=227, name='Omena')>,
#  ('Omena', 'Fillet', None, None): <Commodity(id=783, name='Omena')>,
#  ('Omena', 'Fried', None, None): <Commodity(id=398, name='Omena')>,
#  ('Oranges', None, None, 'male'): <Commodity(id=246, name='Oranges')>,
#  ('Oranges', None, None, None): <Commodity(id=54, name='Oranges')>,
# ...
# 2025-06-20 14:42:48,824 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:48,824 INFO sqlalchemy.engine.Engine [insertmanyvalues 822/832 (ordered)] (1075, 108, datetime.date(2025, 1, 28), 400.0, 20.0, 'Kg', 'KES', 35.0, 'Kg', 'KES', 935, 54, datetime.date(2025, 1, 29), 9000.0, 61.11, 'Kg', 'KES', 50.0, 'Kg', 'KES', 935, 73, datetime.date(2025, 1, 29), 800.0, 75.0, 'Kg', 'KES', 100.0, 'Kg', 'KES', 935, 101, datetime.date(2025, 1, 29), 2700.0, 50.0, 'Kg', 'KES', 65.0, 'Kg', 'KES', 935, 67, datetime.date(2025, 1, 29), 9000.0, 44.44, 'Kg', 'KES', 60.0, 'Kg', 'KES' ... 9900 parameters truncated ... 1132, 80, datetime.date(2025, 5, 15), 300.0, 150.0, 'Kg', 'KES', 175.0, 'Kg', 'KES', 1016, 63, datetime.date(2025, 5, 15), 280.0, None, None, 'KES', 160.0, 'Kg', 'KES', 1016, 65, datetime.date(2025, 5, 15), 1500.0, None, None, 'KES', 37.78, 'Kg', 'KES', 1132, 81, datetime.date(2025, 5, 15), 400.0, 125.0, 'Kg', 'KES', 150.0, 'Kg', 'KES', 1132, 118, datetime.date(2025, 5, 15), 300.0, 125.0, 'Kg', 'KES', 150.0, 'Kg', 'KES')
# 2025-06-20 14:42:48,846 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:48,846 INFO sqlalchemy.engine.Engine [insertmanyvalues 823/832 (ordered)] (1016, 67, datetime.date(2025, 5, 15), 230.0, None, None, 'KES', 30.0, 'Kg', 'KES', 1132, 82, datetime.date(2025, 5, 15), 200.0, 150.0, 'Kg', 'KES', 175.0, 'Kg', 'KES', 1016, 71, datetime.date(2025, 5, 15), 370.0, None, None, 'KES', 50.0, 'Kg', 'KES', 1132, 126, datetime.date(2025, 5, 15), 500.0, 125.0, 'Kg', 'KES', 140.0, 'Kg', 'KES', 1132, 1, datetime.date(2025, 5, 15), 300.0, 135.0, 'Kg', 'KES', 150.0, 'Kg', 'KES' ... 9900 parameters truncated ... 1041, 181, datetime.date(2025, 5, 20), 200.0, 60.0, 'Kg', 'KES', 120.0, 'Kg', 'KES', 1041, 53, datetime.date(2025, 5, 20), 150.0, 40.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 1041, 122, datetime.date(2025, 5, 20), 280.0, 180.0, 'Kg', 'KES', 250.0, 'Kg', 'KES', 1041, 54, datetime.date(2025, 5, 20), 350.0, 50.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 1041, 401, datetime.date(2025, 5, 20), 300.0, 60.0, 'Kg', 'KES', 120.0, 'Kg', 'KES')
# 2025-06-20 14:42:48,868 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:48,869 INFO sqlalchemy.engine.Engine [insertmanyvalues 824/832 (ordered)] (1041, 113, datetime.date(2025, 5, 20), 150.0, 30.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 1041, 57, datetime.date(2025, 5, 20), 300.0, 25.0, 'Kg', 'KES', 50.0, 'Kg', 'KES', 1041, 58, datetime.date(2025, 5, 20), 200.0, 50.0, 'Kg', 'KES', 100.0, 'Kg', 'KES', 1041, 98, datetime.date(2025, 5, 20), 250.0, 60.0, 'Kg', 'KES', 120.0, 'Kg', 'KES', 1041, 60, datetime.date(2025, 5, 20), 2200.0, 160.0, 'Kg', 'KES', 180.0, 'Kg', 'KES' ... 9900 parameters truncated ... 1016, 128, datetime.date(2025, 5, 21), 370.0, None, None, 'KES', 80.0, 'Kg', 'KES', 1016, 94, datetime.date(2025, 5, 21), 1100.0, None, None, 'KES', 70.0, 'Kg', 'KES', 1008, 139, datetime.date(2025, 5, 21), None, None, None, 'KES', 150.0, 'Kg', 'KES', 1016, 90, datetime.date(2025, 5, 21), 350.0, None, None, 'KES', 80.0, 'Kg', 'KES', 1008, 151, datetime.date(2025, 5, 21), None, None, None, 'KES', 150.0, 'Kg', 'KES')
# 2025-06-20 14:42:48,892 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:48,892 INFO sqlalchemy.engine.Engine [insertmanyvalues 825/832 (ordered)] (1008, 121, datetime.date(2025, 5, 21), None, None, None, 'KES', 280.0, 'Kg', 'KES', 1016, 86, datetime.date(2025, 5, 21), 1280.0, None, None, 'KES', 8.0, 'Kg', 'KES', 1008, 88, datetime.date(2025, 5, 21), None, None, None, 'KES', 180.0, 'Kg', 'KES', 1016, 108, datetime.date(2025, 5, 21), 850.0, None, None, 'KES', 50.0, 'Kg', 'KES', 1008, 119, datetime.date(2025, 5, 21), None, None, None, 'KES', 140.0, 'Kg', 'KES' ... 9900 parameters truncated ... 966, 48, datetime.date(2025, 5, 23), None, None, None, 'KES', 70.0, 'Kg', 'KES', 940, 73, datetime.date(2025, 5, 23), 24000.0, 55.0, 'Kg', 'KES', 60.0, 'Kg', 'KES', 966, 96, datetime.date(2025, 5, 23), None, None, None, 'KES', 150.0, 'Kg', 'KES', 875, 135, datetime.date(2025, 5, 23), 2000.0, 30.0, 'Kg', 'KES', 50.0, 'Kg', 'KES', 940, 74, datetime.date(2025, 5, 23), 2000.0, 40.0, 'Kg', 'KES', 50.0, 'Kg', 'KES')
# 2025-06-20 14:42:48,913 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:48,914 INFO sqlalchemy.engine.Engine [insertmanyvalues 826/832 (ordered)] (875, 136, datetime.date(2025, 5, 23), 100.0, 80.0, 'Kg', 'KES', 100.0, 'Kg', 'KES', 875, 110, datetime.date(2025, 5, 23), 650.0, 60.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 940, 75, datetime.date(2025, 5, 23), 4000.0, 40.0, 'Kg', 'KES', 45.0, 'Kg', 'KES', 875, 108, datetime.date(2025, 5, 23), 28000.0, 25.0, 'Kg', 'KES', 40.0, 'Kg', 'KES', 940, 140, datetime.date(2025, 5, 23), 3000.0, 50.0, 'Kg', 'KES', 80.0, 'Kg', 'KES' ... 9900 parameters truncated ... 1041, 151, datetime.date(2025, 5, 27), 1200.0, 100.0, 'Kg', 'KES', 140.0, 'Kg', 'KES', 1041, 121, datetime.date(2025, 5, 27), 1350.0, 280.0, 'Kg', 'KES', 350.0, 'Kg', 'KES', 1041, 83, datetime.date(2025, 5, 27), 800.0, 280.0, 'Kg', 'KES', 350.0, 'Kg', 'KES', 1041, 85, datetime.date(2025, 5, 27), 1650.0, 135.0, 'Kg', 'KES', 175.0, 'Kg', 'KES', 1041, 87, datetime.date(2025, 5, 27), 1800.0, 120.0, 'Kg', 'KES', 150.0, 'Kg', 'KES')
# 2025-06-20 14:42:48,938 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:48,938 INFO sqlalchemy.engine.Engine [insertmanyvalues 827/832 (ordered)] (982, 113, datetime.date(2025, 5, 27), 250.0, 40.0, 'Kg', 'KES', 60.0, 'Kg', 'KES', 1041, 88, datetime.date(2025, 5, 27), 1500.0, 130.0, 'Kg', 'KES', 160.0, 'Kg', 'KES', 982, 58, datetime.date(2025, 5, 27), 2500.0, 40.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 1041, 119, datetime.date(2025, 5, 27), 1800.0, 135.0, 'Kg', 'KES', 175.0, 'Kg', 'KES', 1041, 80, datetime.date(2025, 5, 27), 2100.0, 120.0, 'Kg', 'KES', 150.0, 'Kg', 'KES' ... 9900 parameters truncated ... 1087, 85, datetime.date(2025, 5, 28), None, 122.22, 'Kg', 'KES', 140.0, 'Kg', 'KES', 864, 78, datetime.date(2025, 5, 28), 60.0, 250.0, 'Kg', 'KES', 170.0, 'Kg', 'KES', 864, 92, datetime.date(2025, 5, 28), 60.0, 450.0, 'Kg', 'KES', 500.0, 'Kg', 'KES', 864, 101, datetime.date(2025, 5, 28), 170.0, 100.0, 'Kg', 'KES', 110.0, 'Kg', 'KES', 1087, 109, datetime.date(2025, 5, 28), None, 0.01, 'Kg', 'KES', 180.0, 'Kg', 'KES')
# 2025-06-20 14:42:48,964 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:48,964 INFO sqlalchemy.engine.Engine [insertmanyvalues 828/832 (ordered)] (864, 132, datetime.date(2025, 5, 28), 150.0, 100.0, 'Kg', 'KES', 110.0, 'Kg', 'KES', 864, 131, datetime.date(2025, 5, 28), 20.0, 70.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 864, 93, datetime.date(2025, 5, 28), 1700.0, 70.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 1087, 119, datetime.date(2025, 5, 28), None, 83.33, 'Kg', 'KES', 100.0, 'Kg', 'KES', 864, 130, datetime.date(2025, 5, 28), 600.0, 120.0, 'Kg', 'KES', 130.0, 'Kg', 'KES' ... 9900 parameters truncated ... 966, 126, datetime.date(2025, 5, 30), None, 115.0, 'Kg', 'KES', 120.0, 'Kg', 'KES', 966, 112, datetime.date(2025, 5, 30), None, 70.0, 'Kg', 'KES', 90.0, 'Kg', 'KES', 966, 60, datetime.date(2025, 5, 30), None, 160.0, 'Kg', 'KES', 180.0, 'Kg', 'KES', 966, 61, datetime.date(2025, 5, 30), None, 70.0, 'Kg', 'KES', 120.0, 'Kg', 'KES', 966, 127, datetime.date(2025, 5, 30), None, 110.0, 'Kg', 'KES', 120.0, 'Kg', 'KES')
# 2025-06-20 14:42:48,991 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:48,991 INFO sqlalchemy.engine.Engine [insertmanyvalues 829/832 (ordered)] (966, 63, datetime.date(2025, 5, 30), None, 48.6, 'Kg', 'KES', 90.0, 'Kg', 'KES', 966, 65, datetime.date(2025, 5, 30), None, 55.0, 'Kg', 'KES', 65.0, 'Kg', 'KES', 966, 66, datetime.date(2025, 5, 30), None, None, None, 'KES', 80.0, 'Kg', 'KES', 1023, 59, datetime.date(2025, 5, 30), 400.0, 180.0, 'Kg', 'KES', 200.0, 'Kg', 'KES', 1023, 60, datetime.date(2025, 5, 30), 200.0, 150.0, 'Kg', 'KES', 170.0, 'Kg', 'KES' ... 9900 parameters truncated ... 968, 131, datetime.date(2025, 6, 3), 1200.0, 80.0, 'Kg', 'KES', 150.0, 'Kg', 'KES', 875, 96, datetime.date(2025, 6, 3), 450.0, 50.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 931, 58, datetime.date(2025, 6, 3), 2000.0, 40.0, 'Kg', 'KES', 90.0, 'Kg', 'KES', 931, 120, datetime.date(2025, 6, 3), 100.0, 270.0, 'Kg', 'KES', 340.0, 'Kg', 'KES', 931, 112, datetime.date(2025, 6, 3), 300.0, 70.0, 'Kg', 'KES', 80.0, 'Kg', 'KES')
# 2025-06-20 14:42:49,011 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:49,012 INFO sqlalchemy.engine.Engine [insertmanyvalues 830/832 (ordered)] (931, 61, datetime.date(2025, 6, 3), 380.0, 70.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 931, 127, datetime.date(2025, 6, 3), 200.0, 70.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 931, 63, datetime.date(2025, 6, 3), 200.0, 140.0, 'Kg', 'KES', 150.0, 'Kg', 'KES', 931, 65, datetime.date(2025, 6, 3), 13500.0, 55.0, 'Kg', 'KES', 60.0, 'Kg', 'KES', 968, 93, datetime.date(2025, 6, 3), 450.0, 4.0, 'Kg', 'KES', 120.0, 'Kg', 'KES' ... 9900 parameters truncated ... 928, 113, datetime.date(2025, 6, 5), None, 40.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 928, 545, datetime.date(2025, 6, 5), None, 700.0, 'Kg', 'KES', 800.0, 'Kg', 'KES', 928, 284, datetime.date(2025, 6, 5), None, 700.0, 'Kg', 'KES', 800.0, 'Kg', 'KES', 928, 57, datetime.date(2025, 6, 5), None, 70.0, 'Kg', 'KES', 100.0, 'Kg', 'KES', 928, 58, datetime.date(2025, 6, 5), None, 41.67, 'Kg', 'KES', 60.0, 'Kg', 'KES')
# 2025-06-20 14:42:49,032 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 156911 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:49,032 INFO sqlalchemy.engine.Engine [insertmanyvalues 831/832 (ordered)] (928, 120, datetime.date(2025, 6, 5), None, 250.0, 'Kg', 'KES', 300.0, 'Kg', 'KES', 928, 779, datetime.date(2025, 6, 5), None, 55.0, 'Kg', 'KES', 60.0, 'Kg', 'KES', 928, 139, datetime.date(2025, 6, 5), None, 111.11, 'Kg', 'KES', 160.0, 'Kg', 'KES', 928, 121, datetime.date(2025, 6, 5), None, 200.0, 'Kg', 'KES', 300.0, 'Kg', 'KES', 928, 83, datetime.date(2025, 6, 5), None, 230.0, 'Kg', 'KES', 300.0, 'Kg', 'KES' ... 9900 parameters truncated ... 961, 54, datetime.date(2025, 6, 9), None, None, None, 'KES', 130.0, 'Kg', 'KES', 875, 135, datetime.date(2025, 6, 9), 2000.0, 40.0, 'Kg', 'KES', 60.0, 'Kg', 'KES', 888, 84, datetime.date(2025, 6, 9), 16100.0, None, None, 'KES', 310.0, 'Kg', 'KES', 961, 401, datetime.date(2025, 6, 9), None, None, None, 'KES', 80.0, 'Kg', 'KES', 875, 136, datetime.date(2025, 6, 9), 150.0, 80.0, 'Kg', 'KES', 120.0, 'Kg', 'KES')
# 2025-06-20 14:42:49,054 INFO sqlalchemy.engine.Engine INSERT INTO farmbase_core.market_price (market_id, commodity_id, date, supply_volume, wholesale_price, wholesale_unit, wholesale_ccy, retail_price, retail_unit, retail_ccy) SELECT p0::INTEGER, p1::INTEGER, p2::DATE, p3::FLOAT, p4::FLOAT, p5::VARCHAR, ... 16290 characters truncated ... ORDER BY sen_counter RETURNING farmbase_core.market_price.id, farmbase_core.market_price.id AS id__1
# 2025-06-20 14:42:49,055 INFO sqlalchemy.engine.Engine [insertmanyvalues 832/832 (ordered)] (875, 110, datetime.date(2025, 6, 9), 400.0, 50.0, 'Kg', 'KES', 80.0, 'Kg', 'KES', 961, 141, datetime.date(2025, 6, 9), None, None, None, 'KES', 80.0, 'Kg', 'KES', 961, 113, datetime.date(2025, 6, 9), None, None, None, 'KES', 60.0, 'Kg', 'KES', 875, 108, datetime.date(2025, 6, 9), 25000.0, 30.0, 'Kg', 'KES', 45.0, 'Kg', 'KES', 961, 185, datetime.date(2025, 6, 9), None, None, None, 'KES', 250.0, 'Kg', 'KES' ... 1000 parameters truncated ... 1143, 766, datetime.date(2025, 6, 9), 22.0, 280.0, ' Kg', 'KES', 350.0, ' Kg', 'KES', 1143, 756, datetime.date(2025, 6, 9), 24.0, 250.0, 'Kg', 'KES', 330.0, 'Kg', 'KES', 1143, 356, datetime.date(2025, 6, 9), 58.0, 200.0, 'Kg', 'KES', 270.0, 'Kg', 'KES', 1143, 385, datetime.date(2025, 6, 9), 76.0, 100.0, 'Kg', 'KES', 150.0, 'Kg', 'KES', 1143, 402, datetime.date(2025, 6, 9), 31.0, 100.0, 'Kg', 'KES', 160.0, 'Kg', 'KES')
# 2025-06-20 14:43:00,524 INFO sqlalchemy.engine.Engine COMMIT
#
# Successfully loaded all market prices into the database.

# %%
print()
